# %% [markdown]
# ## Databricks notebooks

# %%
print("hello")

# %%
# %sql
select "Run SQl"

# %% [markdown]
# ### Data Objects
#
# - Catalog
# - schema
# - tables, views, volumes, functions

# %% [markdown]
# ![](/Volumes/acc_dev/naval/raw/object-model.png)

# %%
# %sql
use catalog acc_dev;
create schema if not exists naval;

# %%
# %sql
use catalog acc_dev;
use schema naval;

# %%
# %sql
create table acc_dev.naval.demo (id int primary key)
