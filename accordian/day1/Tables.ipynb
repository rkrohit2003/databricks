# %%
Methods to create a table

1. pyspark dataframe
2. CTAS  (select * from fileformat.'' or select * from read_files("path"))
3. UI

# %%
# %sql
select 
  count_if(order_id is null) as order_id_nulls,
  count_if(customerid is null) as customerid_nulls,
  count_if(transaction_id is null) as transaction_id_nulls,
  count_if(product_id is null) as product_id_nulls,
  count_if(quantity is null) as quantity_nulls,
  count_if(discount_amount is null) as discount_amount_nulls,
  count_if(total_amount is null) as total_amount_nulls,
  count_if(order_date is null) as order_date_nulls
from acc_dev.naval.sales
