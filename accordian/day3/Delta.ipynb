-- %%
use catalog acc_dev;
use schema naval;

-- %%
create table if not exists emp(id int, name string, city string)

-- %%
insert into emp values (1,'Naval','Solapur')

-- %%
insert into emp values (3,'Krishna','Hyd'),(4,'krish','Pune')

-- %%
select * from emp

-- %%
desc extended emp

-- %%
desc history emp

-- %%
desc detail emp

-- %%
delete from emp where id=1

-- %% [markdown]
-- ## Time travel

-- %%
select * from emp version as of 3

-- %%
select * from emp

-- %%
select * from emp timestamp as of '2025-11-05T05:09:38.000+00:00'

-- %%
delete from emp

-- %%
select * from emp

-- %% [markdown]
-- ## restore

-- %%
%python
df1=spark.sql("select * from emp version as of 3")

-- %%
%python
df1.display()

-- %%
restore table emp to version as of 25
