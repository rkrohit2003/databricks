# %%
# %run "/Workspace/Users/navallyemul@gmail.com/accordian/day3/multi hop/includes"

# %%
# reader
df=spark.table(f"{catalog}.{schema}.sales")

#transform
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

#write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.naval_silver.sales_cleaned")

# %%
    # %sql
--select * from acc_dev.naval_bronze.sales
-- select distinct * from acc_dev.naval_bronze.sales where order_id is not null
